# %%
import requests
import pandas as pd
import random
import json

# Step 1: Fetch all available indicators
print("Fetching list of indicators...")
indicators_url = 'https://ghoapi.azureedge.net/api/Indicator'
response = requests.get(indicators_url)
indicators_data = response.json()['value']

print(f"Total indicators available: {len(indicators_data)}")

# Step 2: Randomly select 10 indicators
random_indicators = random.sample(indicators_data, 100)

print("\n=== Selected 10 Random Indicators ===")
for i, indicator in enumerate(random_indicators, 1):
    print(f"{i}. {indicator['IndicatorCode']}: {indicator['IndicatorName']}")

# Step 3: Download data for each selected indicator
all_data = []
indicator_summary = []

for indicator in random_indicators:
    code = indicator['IndicatorCode']
    name = indicator['IndicatorName']
    
    print(f"\nDownloading data for: {code}...")
    
    try:
        # Fetch data for this indicator
        data_url = f'https://ghoapi.azureedge.net/api/{code}'
        data_response = requests.get(data_url)
        
        if data_response.status_code == 200:
            indicator_records = data_response.json().get('value', [])
            
            # Add indicator info to each record
            for record in indicator_records:
                record['IndicatorCode'] = code
                record['IndicatorName'] = name
            
            all_data.extend(indicator_records)
            
            # Summary statistics
            indicator_summary.append({
                'IndicatorCode': code,
                'IndicatorName': name,
                'NumberOfRecords': len(indicator_records)
            })
            
            print(f"  ✓ Retrieved {len(indicator_records)} records")
        else:
            print(f"  ✗ Error: Status code {data_response.status_code}")
            
    except Exception as e:
        print(f"  ✗ Error downloading {code}: {str(e)}")

# Step 4: Convert to DataFrames and save
print("\n=== Saving data ===")

# Save all data to CSV
if all_data:
    df_all = pd.DataFrame(all_data)
    df_all.to_csv('who_gho_data_all_indicators.csv', index=False)
    print(f"✓ Saved all data to 'who_gho_data_all_indicators.csv' ({len(df_all)} total records)")

# Save summary
if indicator_summary:
    df_summary = pd.DataFrame(indicator_summary)
    df_summary.to_csv('who_gho_indicators_summary.csv', index=False)
    print(f"✓ Saved summary to 'who_gho_indicators_summary.csv'")

# Optional: Save each indicator to separate CSV files
print("\n=== Saving individual indicator files ===")
for indicator in random_indicators:
    code = indicator['IndicatorCode']
    indicator_df = df_all[df_all['IndicatorCode'] == code]
    
    if not indicator_df.empty:
        filename = f'who_gho_{code}.csv'
        indicator_df.to_csv(filename, index=False)
        print(f"✓ Saved {filename} ({len(indicator_df)} records)")

print("\n=== Download Complete! ===")
print(f"Total indicators: {len(random_indicators)}")
print(f"Total records: {len(all_data)}")
# Out:
# Fetching list of indicators...
# Total indicators available: 3039
#
# === Selected 10 Random Indicators ===
# 1. PRISON_C16_LABTESTS: In-prison laboratory tests
# 2. GDO_q2x3: Existence of dementia sub-national plan(s)
# 3. RSUD_390: Self-help groups
# 4. TB_rdst_num: The number of people with susceptibility test result for rifampicin among bacteriologically confirmed pulmonary TB patients.
# 5. MH_15: Beds in community residential facilities (per 100,000)
# 6. WHS9_93: Gross national income per capita (PPP int. $)
# 7. overwgt3: Overweight prevalence in children aged <three years (%)
# 8. WHS7_103: Private prepaid plans as a percentage of private expenditure on health
# 9. Yth_nonsmoked_national: Representation of latest youth prevalence survey (nonsmoked)
# 10. SA_0000001517: Restrictions on product placement on cable television
# 11. WHS3_46: Total tetanus - number of reported cases
# 12. NCD_CCS_TransFat: Existence of national policies on trans-fatty acid elimination
# 13. NCD_HYP_CONTROL_C: Hypertension: effective treatment coverage (controlled hypertension) among adults aged 30-79 with hypertension, crude (%)
# 14. EMFLIMITMAGNETIC: Magnetic flux density (microT)
# 15. RS_210: Applicability of seat-belt law to all occupants
# 16. SA_0000001506_ARCHIVED: National legislation to prevent illegal alcohol
# 17. FOODBORNE_YLL_100K_LT5: Foodborne years of life lost per 100 000, aged less than 5 years
# 18. MALARIA_INDIG: Number of indigenous malaria cases
# 19. SA_0000001504: Alcohol use is banned
# 20. NCD_CCS_PA_POL_PUBLIC: Existence of policy promoting physical activity: public open spaces
# 21. TOBACCO_MPOWER_M1_TOBACCOUSESMOKING: Tobacco Monitor: M1 population-based national surveys, tobacco use and smoking
# 22. SA_0000001771_ARCHIVED: Comprehensive and regular reporting of alcohol situation
# 23. R_admin_unique_identifier: Tobacco tax administration: Unique identifier
# 24. M_svy_national_youth: Representativeness of youth survey
# 25. SDGODAWS: Amount of water- and sanitation-related official development assistance that is part of a government-coordinated spending plan (constant 2023 US$ millions)
# 26. W6_font_A: Does the law mandate font style, font size and colour of health warnings on cigarette packaging?
# 27. WHS10_10: International Statistical Classification of Diseases and Related Health Problems (ICD)
# 28. NUT_CF_ZVF: Zero vegetable or fruit consumption, 6-23 months
# 29. NUTUNDERWEIGHTPREV: Underweight prevalence among children under 5 years of age (%), model-based estimates
# 30. NCD_CCS_cancer_surgery: General availability of cancer surgery in the public sector
# 31. CC_8: Climate change  attributable DALYs per 100'000 children under 5 years
# 32. M_Est_smk_daily_std: Estimate of daily tobacco smoking prevalence (%) (age-standardized rate)
# 33. SA_0000001541_ARCHIVED: Restrictions on sales promotion from owners of pubs and bars (alcohol for free)
# 34. RSUD_510: Registration of naloxone for injection for opioid overdose
# 35. GOE_Q168: To define medical jurisdiction, liability or reimbursement of eHealth services such as telehealth
# 36. WHS7_108: Per capita government expenditure on health (PPP int. $)
# 37. TOBACCO_0000000395: Health warnings on other smoked tobacco packaging must be written in the principal language(s) of the country
# 38. SA_0000001502_ARCHIVED: Adopted written national policy on alcohol
# 39. RSUD_26: Governement benefits for persons with substance use disorders
# 40. cpmowho: Contraceptive prevalence - use of modern methods (%)
# 41. RSUD_370: Specialized treatment facilities for alcohol use disorders
# 42. TAXBEV_TOTALTAXES: Total taxes on beverages (%)
# 43. NUTRITION_ANAEMIA_CHILDREN_PREV: Prevalence of anaemia in children aged 6-59 months (%)
# 44. WCO_CSSPRIORITIES: Country Cooperation Strategy Priorities
# 45. TOBACCO_MPOWER_P2_SMOKEFREEPLACEDETAILS: Tobacco Protect people: P2 smoke-free places, additional characteristics
# 46. HEPATITIS_HBV_PREVALENCE_PER100: Prevalence of chronic hepatitis B (HBV) in the general population (%)
# 47. ASSISTIVETECH_SOURCESOFAT: Sources of assistive products (%)
# 48. P15_complaints: National smoking ban: CITIZEN COMPLAINTS AND INVESTIGATIONS
# 49. SA_0000001823: Alcohol, tourist consumption (in litres of pure alcohol), three-year average
# 50. GOE_Q154: Lack of infrastructure
# 51. SG_DMK_SRCR_FN_ZS: Proportion of women aged 15-49 years who make their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (%)
# 52. WHS10_2: Number of cause-of-death registration years available
# 53. NCD_CCS_DIAB_SVY: Has conducted a recent, national adult risk factor survey covering raised blood glucose/diabetes
# 54. SA_0000001523_ARCHIVED: Prices for alcoholic beverages (average, US$)
# 55. NCD_CCS_SurvMonRep9NCD: Existence of an NCD surveillance and monitoring system in place to enable reporting against the nine global NCD targets
# 56. NTD_LEISHVEND: Status of endemicity of visceral leishmaniasis
# 57. WHS9_89: Population proportion under 15 (%)
# 58. SA_0000001806: Legal requirement for size of health warning labels
# 59. W10_graphic_A: Do the health warnings on cigarette packaging include a photograph or graphic?
# 60. UV_2: UV radiation attributable deaths
# 61. HEPATITIS_HCV_DIAGNOSED_NUM: Chronic hepatitis C (HCV) infected persons diagnosed (number)
# 62. HSS_COMPREHENSIVEHEALTHPOLICY: Countries that have a comprehensive national health sector policy/ strategy/ plan with goals and targets updated within the last 5 years
# 63. MH_25: Stand-alone policy or plan for mental health
# 64. PHE_HHAIR_PROP_POP_CATEGORY_FUELS: Proportion of population with primary reliance on fuels and technologies for cooking, by fuel type (%)
# 65. SA_0000001476_ARCHIVED: Alcohol expenditure as a per cent of total household expenditure
# 66. NCD_CCS_DIET_AWARE: Implementation of a nutrition public awareness program
# 67. NCD_CCS_TEL_AML_COMBO: General availability of Fixed dose combination avail (telmisartan + amlodipine) in the public health sector
# 68. NUTSEVWASTINGNUM: Severe wasted numbers among children under 5 years of age (millions), model-based estimates
# 69. SA_0000001432: Age-standardized DALYs, prematurity and low birth rate, per 100,000
# 70. GOE_Q177: Which allows individuals to demand the deletion of health-related data from their EHR
# 71. MALARIA_PRES_CASES: Number of presumed malaria cases
# 72. SA_0000001681: Perceived trend in imports
# 73. WHS2_161: Age-standardized mortality rate by cause (per 100 000 population) - Cardiovascular
# 74. Adult_curr_tob_smoking: Prevalence of current tobacco smoking among adults (%)
# 75. NCD_BMI_18C: Prevalence of underweight among adults, BMI < 18 (crude estimate) (%)
# 76. MORTADO: Adolescent mortality rate (per 1 000 age specific cohort)
# 77. TOBACCO_MPOWER_R_TAXADMINISTRATION: Tobacco Raise taxes: Tax administration
# 78. RADON_Q405: Radon in national drinking-water regulations
# 79. MH_23: Other non-specialized doctors in mental health sector (per 100,000)
# 80. SW_CONDOMUSE_PERCENT: Sex workers: Condom use (percent)
# 81. SDGIHR: Average of 13 International Health Regulations core capacity scores
# 82. M_smkless_svy_national_youth: Representativeness of survey of youth - smokeless
# 83. SA_0000001509: Advertising restrictions on national radio
# 84. GDO_q9x2_2: Residential long-term care beds (per 10 000 population)
# 85. vpolio: Polio immunization coverage among one-year-olds (%)
# 86. RS_194: Number of registered vehicles
# 87. SA_0000001441: Age-standardized death rates, drownings, per 100,000
# 88. GDO_q12x2x1x1_3PRV: Majority provider of respite care for dementia carers (Private sector)
# 89. SA_0000001652: Interventions, projects, training
# 90. R_Ad_val_estimate: Most sold brand of cigarettes - taxes as a % of price - ad valorem excise
# 91. GOE_Q174: Which allows for the sharing of personal and health data between research entities
# 92. FOODBORNE_YLL_CASE_GE5: Foodborne years of life lost per case, aged 5 years and above
# 93. AMR_INFECT_ECOLI: Proportion of bloodstream infection due to Escherichia coli resistant to third-generation cephalosporins (%)
# 94. GDO_q5x1x1_8: Identification of different sectors in dementia care coordination (Private sector)
# 95. M_svy_yr_youth: Year of survey of youth
# 96. NCD_CCS_PA_TAX: Existence of tax incentives to promote physical activity
# 97. SA_0000001686: Exports of wine (grape) in 1000s hectolitres
# 98. HWF_0009: Midwifery personnel (number)
# 99. E21_vending_machines: Complete ban on tobacco vending machines
# 100. NCD_CCS_sulphonylurea: General availability of sulphonylurea(s) in the public health sector
#
# Downloading data for: PRISON_C16_LABTESTS...
#   ✓ Retrieved 36 records
#
# Downloading data for: GDO_q2x3...
#   ✓ Retrieved 61 records
#
# Downloading data for: RSUD_390...
#   ✓ Retrieved 970 records
#
# Downloading data for: TB_rdst_num...
#   ✓ Retrieved 1899 records
#
# Downloading data for: MH_15...
#   ✓ Retrieved 58 records
#
# Downloading data for: WHS9_93...
#   ✓ Retrieved 0 records
#
# Downloading data for: overwgt3...
#   ✓ Retrieved 0 records
#
# Downloading data for: WHS7_103...
#   ✓ Retrieved 0 records
#
# Downloading data for: Yth_nonsmoked_national...
#   ✓ Retrieved 165 records
#
# Downloading data for: SA_0000001517...
#   ✓ Retrieved 582 records
#
# Downloading data for: WHS3_46...
#   ✓ Retrieved 8853 records
#
# Downloading data for: NCD_CCS_TransFat...
#   ✓ Retrieved 388 records
#
# Downloading data for: NCD_HYP_CONTROL_C...
#   ✓ Retrieved 19170 records
#
# Downloading data for: EMFLIMITMAGNETIC...
#   ✓ Retrieved 108 records
#
# Downloading data for: RS_210...
#   ✓ Retrieved 175 records
#
# Downloading data for: SA_0000001506_ARCHIVED...
#   ✓ Retrieved 55 records
#
# Downloading data for: FOODBORNE_YLL_100K_LT5...
#   ✓ Retrieved 0 records
#
# Downloading data for: MALARIA_INDIG...
#   ✓ Retrieved 937 records
#
# Downloading data for: SA_0000001504...
#   ✓ Retrieved 10 records
#
# Downloading data for: NCD_CCS_PA_POL_PUBLIC...
#   ✓ Retrieved 194 records
#
# Downloading data for: TOBACCO_MPOWER_M1_TOBACCOUSESMOKING...
#   ✓ Retrieved 1170 records
#
# Downloading data for: SA_0000001771_ARCHIVED...
#   ✓ Retrieved 52 records
#
# Downloading data for: R_admin_unique_identifier...
#   ✓ Retrieved 195 records
#
# Downloading data for: M_svy_national_youth...
#   ✓ Retrieved 0 records
#
# Downloading data for: SDGODAWS...
#   ✓ Retrieved 2059 records
#
# Downloading data for: W6_font_A...
#   ✓ Retrieved 1755 records
#
# Downloading data for: WHS10_10...
#   ✓ Retrieved 0 records
#
# Downloading data for: NUT_CF_ZVF...
#   ✓ Retrieved 7102 records
#
# Downloading data for: NUTUNDERWEIGHTPREV...
#   ✓ Retrieved 1400 records
#
# Downloading data for: NCD_CCS_cancer_surgery...
#   ✓ Retrieved 194 records
#
# Downloading data for: CC_8...
#   ✓ Retrieved 8 records
#
# Downloading data for: M_Est_smk_daily_std...
#   ✓ Retrieved 0 records
#
# Downloading data for: SA_0000001541_ARCHIVED...
#   ✓ Retrieved 336 records
#
# Downloading data for: RSUD_510...
#   ✓ Retrieved 194 records
#
# Downloading data for: GOE_Q168...
#   ✓ Retrieved 121 records
#
# Downloading data for: WHS7_108...
#   ✓ Retrieved 0 records
#
# Downloading data for: TOBACCO_0000000395...
#   ✓ Retrieved 0 records
#
# Downloading data for: SA_0000001502_ARCHIVED...
#   ✓ Retrieved 43 records
#
# Downloading data for: RSUD_26...
#   ✓ Retrieved 276 records
#
# Downloading data for: cpmowho...

# %%
import requests
import pandas as pd
import random
import json

# Step 1: Fetch all available indicators
print("Fetching list of indicators...")
indicators_url = 'https://ghoapi.azureedge.net/api/Indicator'
response = requests.get(indicators_url)
indicators_data = response.json()['value']

print(f"Total indicators available: {len(indicators_data)}")

# Step 2: Randomly select 10 indicators
random_indicators = random.sample(indicators_data, 10)

print("\n=== Selected 10 Random Indicators ===")
for i, indicator in enumerate(random_indicators, 1):
    print(f"{i}. {indicator['IndicatorCode']}: {indicator['IndicatorName']}")

# Step 3: Download data for each selected indicator
all_data = []
indicator_summary = []

for indicator in random_indicators:
    code = indicator['IndicatorCode']
    name = indicator['IndicatorName']
    
    print(f"\nDownloading data for: {code}...")
    
    try:
        # Fetch data for this indicator
        data_url = f'https://ghoapi.azureedge.net/api/{code}'
        data_response = requests.get(data_url)
        
        if data_response.status_code == 200:
            indicator_records = data_response.json().get('value', [])
            
            # Add indicator info to each record
            for record in indicator_records:
                record['IndicatorCode'] = code
                record['IndicatorName'] = name
            
            all_data.extend(indicator_records)
            
            # Summary statistics
            indicator_summary.append({
                'IndicatorCode': code,
                'IndicatorName': name,
                'NumberOfRecords': len(indicator_records)
            })
            
            print(f"  ✓ Retrieved {len(indicator_records)} records")
        else:
            print(f"  ✗ Error: Status code {data_response.status_code}")
            
    except Exception as e:
        print(f"  ✗ Error downloading {code}: {str(e)}")

# Step 4: Convert to DataFrames and save
print("\n=== Saving data ===")

# Save all data to CSV
if all_data:
    df_all = pd.DataFrame(all_data)
    df_all.to_csv('who_gho_data_all_indicators.csv', index=False)
    print(f"✓ Saved all data to 'who_gho_data_all_indicators.csv' ({len(df_all)} total records)")

# Save summary
if indicator_summary:
    df_summary = pd.DataFrame(indicator_summary)
    df_summary.to_csv('who_gho_indicators_summary.csv', index=False)
    print(f"✓ Saved summary to 'who_gho_indicators_summary.csv'")

# Optional: Save each indicator to separate CSV files
print("\n=== Saving individual indicator files ===")
for indicator in random_indicators:
    code = indicator['IndicatorCode']
    indicator_df = df_all[df_all['IndicatorCode'] == code]
    
    if not indicator_df.empty:
        filename = f'who_gho_{code}.csv'
        indicator_df.to_csv(filename, index=False)
        print(f"✓ Saved {filename} ({len(indicator_df)} records)")

print("\n=== Download Complete! ===")
print(f"Total indicators: {len(random_indicators)}")
print(f"Total records: {len(all_data)}")
# Out:
# Fetching list of indicators...
# Total indicators available: 3039
#
# === Selected 10 Random Indicators ===
# 1. SA_0000001727_ARCHIVED: Sobriety checkpoints
# 2. E1_nat_tv_radio: Ban on advertising: National TV and radio
# 3. UHC_TB_DT: Tuberculosis detection and treatment
# 4. SW_PSE_NUM: Sex workers: Population size estimate (number)
# 5. WHOSIS_000012: Prevalence of smoking any tobacco product among adults (&#8805;15 years) (%)
# 6. GDO_q9x4_2: Adult day centre places (per 10,000 population)
# 7. SA_0000001760_ARCHIVED: 15-19 years old total alcohol consumption in litres of pure alcohol
# 8. MSM_CONDOMUSE_PERCENT: Men who have sex with men: Condom use (percent)
# 9. SA_0000001830: Average price 750 mls Wine in US$
# 10. HRH_04: Number of pharmacists
#
# Downloading data for: SA_0000001727_ARCHIVED...
#   ✓ Retrieved 108 records
#
# Downloading data for: E1_nat_tv_radio...
#   ✓ Retrieved 1755 records
#
# Downloading data for: UHC_TB_DT...
#   ✓ Retrieved 0 records
#
# Downloading data for: SW_PSE_NUM...
#   ✓ Retrieved 353 records
#
# Downloading data for: WHOSIS_000012...
#   ✓ Retrieved 0 records
#
# Downloading data for: GDO_q9x4_2...
#   ✓ Retrieved 61 records
#
# Downloading data for: SA_0000001760_ARCHIVED...
#   ✓ Retrieved 582 records
#
# Downloading data for: MSM_CONDOMUSE_PERCENT...
#   ✓ Retrieved 420 records
#
# Downloading data for: SA_0000001830...
#   ✓ Retrieved 132 records
#
# Downloading data for: HRH_04...
#   ✓ Retrieved 0 records
#
# === Saving data ===
# ✓ Saved all data to 'who_gho_data_all_indicators.csv' (3411 total records)
# ✓ Saved summary to 'who_gho_indicators_summary.csv'
#
# === Saving individual indicator files ===
# ✓ Saved who_gho_SA_0000001727_ARCHIVED.csv (108 records)
# ✓ Saved who_gho_E1_nat_tv_radio.csv (1755 records)
# ✓ Saved who_gho_SW_PSE_NUM.csv (353 records)
# ✓ Saved who_gho_GDO_q9x4_2.csv (61 records)
# ✓ Saved who_gho_SA_0000001760_ARCHIVED.csv (582 records)
# ✓ Saved who_gho_MSM_CONDOMUSE_PERCENT.csv (420 records)
# ✓ Saved who_gho_SA_0000001830.csv (132 records)
#
# === Download Complete! ===
# Total indicators: 10
# Total records: 3411
